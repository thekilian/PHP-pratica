# %% [markdown]
# ## Lista de Presença

# %%
print("LISTA DE PRESENÇA")

print('-'*40)
print("Código Aluno \t Nome \t\t\t\t Assinatura")


for num in range(1,31):
    # converte num pra string
    num = str(num)
    print(num + ('_'*15) +'  '+ ('_'*30) +'  '+ ('_'*20))
# Out:
# LISTA DE PRESENÇA
# ----------------------------------------
# Código Aluno 	 Nome 				 Assinatura
# 1_______________  ______________________________  ____________________
# 2_______________  ______________________________  ____________________
# 3_______________  ______________________________  ____________________
# 4_______________  ______________________________  ____________________
# 5_______________  ______________________________  ____________________
# 6_______________  ______________________________  ____________________
# 7_______________  ______________________________  ____________________
# 8_______________  ______________________________  ____________________
# 9_______________  ______________________________  ____________________
# 10_______________  ______________________________  ____________________
# 11_______________  ______________________________  ____________________
# 12_______________  ______________________________  ____________________
# ...
